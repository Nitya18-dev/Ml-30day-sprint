# %% [markdown]
# ***PYTHON PANDAS***

# %%
#KEY DATA STRUCTURE-
#1. series - 1d
#2. dataframe - 2d

# %%
import pandas as pd

# %%
s=pd.Series([1,2,3,4,5], index=('a','b','c','d','e'))
print(s)
#labelled array
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df=pd.DataFrame({"name:" : ["ram","laxman", "aman"], "marks:" : [100,120,99]})
df
# Out:
#     name:  marks:
# 0     ram     100
# 1  laxman     120
# 2    aman      99

# %%
#reading csv
csv=pd.read_csv("data.csv")
csv
# Out:
#       rno        name  age gender Exam_centre       Level     city  \
# 0   11111       Aryan   22      M      Oxford       inter   Jaipur
# 1   11112   Aishwarya   19      F       Rawat  foundation     Kota
# 2   11113        Ansh   24      M         JVP       final   Jaipur
# 3   11114    Anuradha   21      F      Oxford       inter    Alwar
# 4   11115       Kajol   19      F         JVP  foundation   Jaipur
# 5   11116     Kareena   23      F       Rawat       final     Kota
# 6   11117      Kartik   22      M         JVP       inter    Alwar
# 7   11118     Katrina   21      F      Oxford       inter    Alwar
# 8   11119      Lavina   25      F         JVP       final  Bikaner
# 9   11120      Lavish   25      M         JVP       final    Alwar
# 10  11121      Manish   24      M      Oxford       inter  Bikaner
# 11  11122       Manju   20      F       Rawat  foundation   Jaipur
# 12  11123      Nikhil   19      M         JVP  foundation  Bikaner
# ...

# %%
csv5= csv.head(5)
csv_5= csv.tail(5)
print(csv5)
print(csv_5)
# Out:
#      rno       name  age gender Exam_centre       Level    city  Accountany  \
# 0  11111      Aryan   22      M      Oxford       inter  Jaipur          55
# 1  11112  Aishwarya   19      F       Rawat  foundation    Kota          45
# 2  11113       Ansh   24      M         JVP       final  Jaipur          47
# 3  11114   Anuradha   21      F      Oxford       inter   Alwar          57
# 4  11115      Kajol   19      F         JVP  foundation  Jaipur          45
#
#    Economics  LR  english  Law  total  percentage passing_status
# 0         56  50       55   41    257       85.66           Pass
# 1         47  49       41   56    238       79.33           Pass
# 2         32  40       52   21    192       64.00           Pass
# 3         52  51       54   36    250       83.33           Pass
# 4         55  51       58   60    269       89.66           Pass
#       rno     name  age gender Exam_centre       Level     city  Accountany  \
# ...

# %%
csv.describe()
# Out:
#                rno        age  Accountany  Economics         LR    english  \
# count     49.00000  49.000000   49.000000  49.000000  49.000000  49.000000
# mean   11135.00000  22.306122   41.040816  41.142857  40.897959  41.959184
# std       14.28869   2.459709   13.693002  14.531575  11.916803  12.726218
# min    11111.00000  18.000000   12.000000   9.000000  12.000000  16.000000
# 25%    11123.00000  21.000000   30.000000  32.000000  32.000000  32.000000
# 50%    11135.00000  22.000000   42.000000  45.000000  41.000000  44.000000
# 75%    11147.00000  24.000000   53.000000  52.000000  51.000000  52.000000
# max    11159.00000  26.000000   60.000000  60.000000  59.000000  60.000000
#
#              Law       total  percentage
# count  49.000000   49.000000   49.000000
# mean   41.673469  207.448980   69.147347
# std    13.432529   50.051249   16.683387
# min     9.000000   72.000000   24.000000
# 25%    32.000000  175.000000   58.330000
# 50%    42.000000  216.000000   72.000000
# ...

# %%
csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rno             49 non-null     int64
#  1   name            49 non-null     object
#  2   age             49 non-null     int64
#  3   gender          49 non-null     object
#  4   Exam_centre     49 non-null     object
#  5   Level           49 non-null     object
#  6   city            49 non-null     object
#  7   Accountany      49 non-null     int64
#  8   Economics       49 non-null     int64
#  9   LR              49 non-null     int64
#  10  english         49 non-null     int64
#  11  Law             49 non-null     int64
#  12  total           49 non-null     int64
#  13  percentage      49 non-null     float64
#  14  passing_status  49 non-null     object
# dtypes: float64(1), int64(8), object(6)
# memory usage: 5.9+ KB

# %% [markdown]
# Data Selection

# %%
csv[["rno","passing_status"]].head(10)
# Out:
#      rno passing_status
# 0  11111           Pass
# 1  11112           Pass
# 2  11113           Pass
# 3  11114           Pass
# 4  11115           Pass
# 5  11116           Pass
# 6  11117           Pass
# 7  11118           Pass
# 8  11119           Pass
# 9  11120           Pass

# %%
csv.iloc[0] #only first row
# Out:
# rno                11111
# name               Aryan
# age                   22
# gender                 M
# Exam_centre       Oxford
# Level              inter
# city              Jaipur
# Accountany            55
# Economics             56
# LR                    50
# english               55
# Law                   41
# total                257
# percentage         85.66
# passing_status      Pass
# Name: 0, dtype: object

# %%
csv.rename(columns={"percentage":"percent"})

# %%
def fx(a):
    return a + 1

csv["zeros"]= [0 for i in range(len(csv))]
csv["zeros + 1"]= csv["zeros"].apply(fx)

# %%
csv
# Out:
#       rno        name  age gender Exam_centre       Level     city  \
# 0   11111       Aryan   22      M      Oxford       inter   Jaipur
# 1   11112   Aishwarya   19      F       Rawat  foundation     Kota
# 2   11113        Ansh   24      M         JVP       final   Jaipur
# 3   11114    Anuradha   21      F      Oxford       inter    Alwar
# 4   11115       Kajol   19      F         JVP  foundation   Jaipur
# 5   11116     Kareena   23      F       Rawat       final     Kota
# 6   11117      Kartik   22      M         JVP       inter    Alwar
# 7   11118     Katrina   21      F      Oxford       inter    Alwar
# 8   11119      Lavina   25      F         JVP       final  Bikaner
# 9   11120      Lavish   25      M         JVP       final    Alwar
# 10  11121      Manish   24      M      Oxford       inter  Bikaner
# 11  11122       Manju   20      F       Rawat  foundation   Jaipur
# 12  11123      Nikhil   19      M         JVP  foundation  Bikaner
# ...
